# %% [markdown]
# # LV 0.
#
# 분수의 덧셈
#
# https://school.programmers.co.kr/learn/courses/30/lessons/120808

# %% [markdown]
# **문제 설명**
#
#     첫 번째 분수의 분자와 분모를 뜻하는 numer1, denom1, 두 번째 분수의 분자와 분모를 뜻하는 numer2, denom2가 매개변수로 주어집니다. 두 분수를 더한 값을 기약 분수로 나타냈을 때 분자와 분모를 순서대로 담은 배열을 return 하도록 solution 함수를 완성해보세요.
#
# **제한 사항**
#
#     0 <numer1, denom1, numer2, denom2 < 1,000
#
# **입출력 예**
#
# ![image.png](attachment:image.png)
#
# **입출력 예 설명**
#
#     입출력 예 #1
#     1 / 2 + 3 / 4 = 5 / 4입니다. 따라서 [5, 4]를 return 합니다.
#
#     입출력 예 #2
#     9 / 2 + 1 / 3 = 29 / 6입니다. 따라서 [29, 6]을 return 합니다.

# %%
def solution(numer1, denom1, numer2, denom2):
    answer = []
    if denom1 == denom2:
        result = [numer1+numer2,denom1]
    
    else:
        if denom1 < denom2:
            if denom2 % denom1 ==0:
                answer = [(numer1*(denom2//denom1))+numer2, denom2]
            else:
                answer = [(numer1*denom2)+(numer2*denom1), denom1*denom2]
        else:
            if denom1 % denom2 ==0:
                answer = [(number2*(denom1//denom2))+numer1, donom2]

            else:
                answer = [(numer1*denom2)+(numer2*donom1), denom1*denom2]
    return answer

# %%
print(solution(1,2,3,4))
print(solution(9,2,1,3))
# Out:
# [5, 4]
# [29, 6]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from fractions import Fraction

def solution(numer1, denom1, numer2, denom2):
    answer = Fraction((numer1*denom2)+(numer2*denom1), denom1*denom2)
    
    return [answer.numerator, answer.denominator]

# %%
print(solution(1,2,3,4))
print(solution(9,2,1,3))
# Out:
# [5, 4]
# [29, 6]

# %%
from fractions import Fraction

numer1, denom1, numer2, denom2 = 9,2,1,3
ans = Fraction((numer1*denom2 + numer2*denom1),denom1*denom2)
print(ans.denominator, ans.numerator)
# Out:
# 6 29

# %% [markdown]
# **다른 사람 풀이**
#
#
# ![image.png](attachment:image.png)

# %%
import math

denum1, num1, denum2, num2 = 9,2,1,3

denum = denum1 * num2 + denum2 * num1
num = num1 * num2

gcd = math.gcd(denum, num)
print(f"denum, num ->{denum}, {num}")
print(f"gcd -> {gcd}")

[denum//gcd, num//gcd]
# Out:
# denum, num ->29, 6
# gcd -> 1
# [29, 6]
