# %% [markdown]
# # LV 0.
#
# 특이한 정렬
#
# https://school.programmers.co.kr/learn/courses/30/lessons/120880

# %% [markdown]
# **문제 설명**
#
#     정수 n을 기준으로 n과 가까운 수부터 정렬하려고 합니다. 이때 n으로부터의 거리가 같다면 더 큰 수를 앞에 오도록 배치합니다. 정수가 담긴 배열 numlist와 정수 n이 주어질 때 numlist의 원소를 n으로부터 가까운 순서대로 정렬한 배열을 return하도록 solution 함수를 완성해주세요.
#
#
# **제한사항**
#
#     1 ≤ n ≤ 10,000
#     1 ≤ numlist의 원소 ≤ 10,000
#     1 ≤ numlist의 길이 ≤ 100
#     numlist는 중복된 원소를 갖지 않습니다.
#
# **입출력 예**
#
# ![image.png](attachment:image.png)
#
# **입출력 예 설명**
#
#     입출력 예 #1
#     4에서 가까운 순으로 [4, 5, 3, 6, 2, 1]을 return합니다.
#     3과 5는 거리가 같으므로 더 큰 5가 앞에 와야 합니다.
#     2와 6은 거리가 같으므로 더 큰 6이 앞에 와야 합니다.
#
#     입출력 예 #2
#     30에서 가까운 순으로 [36, 40, 20, 47, 10, 6, 7000, 10000]을 return합니다.
#     20과 40은 거리가 같으므로 더 큰 40이 앞에 와야 합니다.

# %%
def solution(numlist, n):
    num_dict = {}
    for num in numlist:
        if abs(n-num) in num_dict.keys():
            num_dict[abs(n-num)].append(num)
            num_dict[abs(n-num)].sort(reverse=True)
        else:
            num_dict[abs(n-num)] = [num]

    return sum(dict(sorted(num_dict.items())).values(), [])

# %%
print(solution([1, 2, 3, 4, 5, 6],4))
print(solution([10000,20,36,47,40,6,10,7000],30))
# Out:
# [4, 5, 3, 6, 2, 1]
# [36, 40, 20, 47, 10, 6, 7000, 10000]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
numlist = [1, 2, 3, 4, 5, 6]
n = 4

num_dict = {}

for num in numlist:
    if abs(n-num) in num_dict.keys():
        num_dict[abs(n-num)].append(num)
        num_dict[abs(n-num)].sort(reverse=True)
        
    else:
        num_dict[abs(n-num)] = [num]
        
num_dict = dict(sorted(num_dict.items()))

result = sum(num_dict.values(), [])
result
# Out:
# [4, 5, 3, 6, 2, 1]

# %% [markdown]
# **다른 사람 풀이**
#
# ![image.png](attachment:image.png)

# %% [markdown]
#     - lambda를 이용한 풀이

# %%
numlist = [1, 2, 3, 4, 5, 6]
n = 4

# %%
sorted(numlist, key=lambda x: (abs(x-n), n-x))
# Out:
# [4, 5, 3, 6, 2, 1]

# %% [markdown]
#      - 요소를 리스트 혹은, 튜플로 두개 이상 줄 수 있는데, 앞의 갚이 같을 때는 뒤의 값을 이용해서 나열함.
#     요소가 하나이고 값이 같을 때는 먼저 처리된 수가  나열..(인덱스가 작은 게)

# %%
sorted(numlist, key=lambda x: (abs(x-n), -x))
# Out:
# [4, 5, 3, 6, 2, 1]
