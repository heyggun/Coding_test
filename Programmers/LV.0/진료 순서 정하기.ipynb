# %% [markdown]
# # LV.0
#
# 진료 순서 정하기
#
# https://school.programmers.co.kr/learn/courses/30/lessons/120835

# %% [markdown]
# **문제 설명**
#
#     외과의사 머쓱이는 응급실에 온 환자의 응급도를 기준으로 진료 순서를 정하려고 합니다. 정수 배열 emergency가 매개변수로 주어질 때 응급도가 높은 순서대로 진료 순서를 정한 배열을 return하도록 solution 함수를 완성해주세요.
#
# **제한사항**
#
#     중복된 원소는 없습니다.
#     1 ≤ emergency의 길이 ≤ 10
#     1 ≤ emergency의 원소 ≤ 100
#
# **입출력 예**
#
# ![image.png](attachment:image.png)
#
#
# **입출력 예 설명**
#
#     입출력 예 #1
#     emergency가 [3, 76, 24]이므로 응급도의 크기 순서대로 번호를 매긴 [3, 1, 2]를 return합니다.
#
#     입출력 예 #2
#     emergency가 [1, 2, 3, 4, 5, 6, 7]이므로 응급도의 크기 순서대로 번호를 매긴 [7, 6, 5, 4, 3, 2, 1]를 return합니다.
#
#     입출력 예 #3
#     emergency가 [30, 10, 23, 6, 100]이므로 응급도의 크기 순서대로 번호를 매긴 [2, 4, 3, 5, 1]를 return합니다.

# %%
def solution(emergency):
    tmp = sorted(emergency, reverse=True)
    return [tmp.index(e)+1 for e in emergency]

# %%
print(solution([3, 76, 24]))
print(solution([1, 2, 3, 4, 5, 6, 7]))
print(solution([30, 10, 23, 6, 100]))
# Out:
# [3, 1, 2]
# [7, 6, 5, 4, 3, 2, 1]
# [2, 4, 3, 5, 1]

# %%
emergency = [30, 10, 23, 6, 100]

tmp = sorted(emergency, reverse=True)

[tmp.index(e)+1 for e in emergency]
# Out:
# [2, 4, 3, 5, 1]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **다른 사람 풀이**
#
#     - 내가 쓴 코드는 간결하지만 index를 쓰면 시간 복잡도가 O(N**2) 이고
#     - 아래와 같이 딕셔너리를 사용하면 시간복잡도 측면에서 좋다고 함

# %%
def solution(emergency):
    answer = []
    emer_ls = {e: i + 1 for i, e in enumerate(sorted(emergency)[::-1])}
    for e in emergency:
        answer.append(emer_ls[e])
    return answer

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
emergency = [30, 10, 23, 6, 100]

# %%
emer_dic = {e:idx for idx, e in enumerate(sorted(emergency)[::-1])}
print(emer_dic)
# Out:
# {100: 0, 30: 1, 23: 2, 10: 3, 6: 4}
