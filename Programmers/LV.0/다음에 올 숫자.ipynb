# %% [markdown]
# # LV 0.
#
# 다음에 올 숫자
#
# https://school.programmers.co.kr/learn/courses/30/lessons/120924

# %% [markdown]
# **문제 설명**
#
#     등차수열 혹은 등비수열 common이 매개변수로 주어질 때, 마지막 원소 다음으로 올 숫자를 return 하도록 solution 함수를 완성해보세요.
#
# **제한사항**
#
#      2 < common의 길이 < 1,000
#     -1,000 < common의 원소 < 2,000
#     common의 원소는 모두 정수입니다.
#     등차수열 혹은 등비수열이 아닌 경우는 없습니다.
#     등비수열인 경우 공비는 0이 아닌 정수입니다.
#
# **입출력 예**
#
# ![image.png](attachment:image.png)
#
# **입출력 예 설명**
#
#     입출력 예 #1
#     [1, 2, 3, 4]는 공차가 1인 등차수열이므로 다음에 올 수는 5이다.
#
#     입출력 예 #2
#     [2, 4, 8]은 공비가 2인 등비수열이므로 다음에 올 수는 16이다.

# %%
def solution(common):
    answer = 0  
    
    if common[1]-common[0] == common[2]-common[1]:
        gap = common[1]-common[0]
        answer = common[-1]+gap
        
    else:
        gap = common[1]//common[0]
        answer =common[-1]*gap
    
    return answer

# %%
print(solution([1,2,3,4]))
print(solution([2,4,8]))
# Out:
# 5
# 16

# %%
print(solution([5,7,9,11]))
print(solution([3,9,27]))
# Out:
# 13
# 81

# %% [markdown]
# **다른 사람 풀이**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a,b,c= common[:3]
print(a,b,c)

if (b-a)==(c-b):
    answer = common[-1]+(b-a)
else:
    answer = common[-1]*(b//a)
    
answer
# Out:
# 2 4 8
# 16

# %% [markdown]
#     - 인덱싱을 해서 common에 담긴 1,2,3 까지 가져와서 비교하면 될 일 good
#     - 다음으로 내가 했던 것처럼 등비인지 등차인지 파악한 후 마지막에 담긴 걸로 등차/등비를 적용~!
