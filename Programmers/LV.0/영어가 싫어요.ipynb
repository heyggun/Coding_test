# %% [markdown]
# # LV 0.
#
# 영어가 싫어요
#
# https://school.programmers.co.kr/learn/courses/30/lessons/120894

# %% [markdown]
# **문제 설명**
#
#     영어가 싫은 머쓱이는 영어로 표기되어있는 숫자를 수로 바꾸려고 합니다. 문자열 numbers가 매개변수로 주어질 때, numbers를 정수로 바꿔 return 하도록 solution 함수를 완성해 주세요.
#
# **제한사항**
#
#     numbers는 소문자로만 구성되어 있습니다.
#     numbers는 "zero", "one", "two", "three", "four", "five", "six", "seven", "eight", "nine" 들이 공백 없이 조합되어 있습니다.
#     1 ≤ numbers의 길이 ≤ 50
#     "zero"는 numbers의 맨 앞에 올 수 없습니다.
#
# **입출력 예**
#
# ![image.png](attachment:image.png)
#
# **입출력 예 설명**
#
#     입출력 예 #1
#     "onetwothreefourfivesixseveneightnine"를 숫자로 바꾼 123456789를 return합니다.
#
#     입출력 예 #1
#     "onefourzerosixseven"를 숫자로 바꾼 14067를 return합니다.

# %%
def solution(numbers):
    answer = numbers.replace('zero','0').replace('one','1').replace('two','2').replace('three','3').replace('four','4').replace('five','5').replace('six','6').replace('seven','7').replace('eight','8').replace('nine','9')
    return int(answer)

# %%
print(solution("onetwothreefourfivesixseveneightnine"))
print(solution("onefourzerosixseven"))
# Out:
# 123456789
# 14067

# %% [markdown]
#     - 시간복잡도 때문에 박살날 줄 알았는데 통과되서 다행~

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **다른 사람 풀이**
#
#     - 분명히 LV1 에서 유사한 문제를 본 것 같았는데, 그 때는 저런식으로 무자비한 하드 코딩아니고 dictionary를 썼던 것 같은데..
#     - 좋은 코드 중 하나가 enumerate 를 사용한 것이었음
#
# ![image.png](attachment:image.png)

# %% [markdown]
#     - 혹은 딕셔너리를 사용
#
# ![image.png](attachment:image.png)
