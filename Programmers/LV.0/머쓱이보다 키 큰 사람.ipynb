# %% [markdown]
# # LV 0.
#
# 머쓱이보다 키 큰 사람
#
# https://school.programmers.co.kr/learn/courses/30/lessons/120585

# %% [markdown]
# **문제 설명**
#
#     머쓱이는 학교에서 키 순으로 줄을 설 때 몇 번째로 서야 하는지 궁금해졌습니다. 머쓱이네 반 친구들의 키가 담긴 정수 배열 array와 머쓱이의 키 height가 매개변수로 주어질 때, 머쓱이보다 키 큰 사람 수를 return 하도록 solution 함수를 완성해보세요.
#
#
# **제한 사항**
#
#     1 ≤ array의 길이 ≤ 100
#     1 ≤ height ≤ 200
#     1 ≤ array의 원소 ≤ 200
#
# **입출력 예**
#
# ![image.png](attachment:image.png)
#
# **입출력 예 설명**
#
#     입출력 예 #1
#     149, 180, 192, 170 중 머쓱이보다 키가 큰 사람은 180, 192, 170으로 세 명입니다.
#
#     입출력 예 #2
#     180, 120, 140 중 190보다 큰 수는 없으므로 0명입니다.

# %%
def solution(array, height):
    answer = -1
    
    for idx,a in enumerate(array):
        if height >=a:
            answer= len(array[idx+1:])
    
    if answer==-1:
        answer =0
        
    return answer

# %%
print(solution([149, 180, 192, 170],167))
print(solution([180, 120, 140],190))
# Out:
# 3
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(array, height):
    answer = 0
    
    for idx,a in enumerate(array):
        if height <=a:
            answer= len(array)-idx
            break
        
    return answer

# %%
print(solution([149, 180, 192, 170],167))
print(solution([180, 120, 140],190))
# Out:
# 3
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(array, height):
    answer = 0
    
    for idx,a in enumerate(array):
        if height <a:
            answer= len(array)-idx
            break
        
    return answer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **다른 사람 풀이**
#
# ![image.png](attachment:image.png)

# %%
def solution(array, height):
    array.append(height)
    array.sort(reverse=True)
    return array.index(height)

# %% [markdown]
#     - array에 height를 넣고, sort를 한다음에 인덱스로 찾는 개 멋진 코드

# %%
array = [149, 180, 192, 170]
height = 167

array.append(height)
array.sort(reverse=True)
print(array)

print(array.index(height))
# Out:
# [192, 180, 170, 167, 149]
# 3

# %% [markdown]
#     - boolean 을 이용하여 리스트 sum 하는 멋진 로직도 있음

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sum([1 for a in array if a>height])
# Out:
# 3
