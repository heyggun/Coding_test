# %% [markdown]
# ## LV 1.
#
# 정수 제곱근 판별
#
# https://school.programmers.co.kr/learn/courses/30/lessons/12934

# %% [markdown]
# **문제 설명**
#
#     임의의 양의 정수 n에 대해, n이 어떤 양의 정수 x의 제곱인지 아닌지 판단하려 합니다.
#     n이 양의 정수 x의 제곱이라면 x+1의 제곱을 리턴하고, n이 양의 정수 x의 제곱이 아니라면 -1을 리턴하는 함수를 완성하세요.
#
# **제한 사항**
#
#     n은 1이상, 50000000000000 이하인 양의 정수입니다.
#
# **입출력 예**
#
# ![image.png](attachment:image.png)
#
# **입출력 예 설명**
#
#     입출력 예#1
#     121은 양의 정수 11의 제곱이므로, (11+1)를 제곱한 144를 리턴합니다.
#
#     입출력 예#2
#     3은 양의 정수의 제곱이 아니므로, -1을 리턴합니다.

# %%
def solution(n):
    tmp = [i for i in range(1, int(n**0.5)+1) if i**2==n]
    return -1 if len(tmp)==0 else (tmp[0]+1)**2

# %%
print(solution(121))
print(solution(3))
# Out:
# 144
# -1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **다른 사람 풀이**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = 121

sqrt = num**(0.5)

if sqrt%1==0:
    answer = int((sqrt+1)**2)
else:
    answer = -1
    
answer
# Out:
# 144

# %%
num = 3

sqrt = num**(0.5)
print(sqrt)

if sqrt%1==0:
    answer = int((sqrt+1)**2)
else:
    answer = -1
    
answer
# Out:
# 1.7320508075688772
# -1
