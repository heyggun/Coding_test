# %% [markdown]
# # LV2.
#
# 행렬의 곱셈
#
# https://school.programmers.co.kr/learn/courses/30/lessons/12949

# %% [markdown]
# **문제 설명**
#
#     2차원 행렬 arr1과 arr2를 입력받아, arr1에 arr2를 곱한 결과를 반환하는 함수, solution을 완성해주세요.
#
# **제한 조건**
#
#     행렬 arr1, arr2의 행과 열의 길이는 2 이상 100 이하입니다.
#     행렬 arr1, arr2의 원소는 -10 이상 20 이하인 자연수입니다.
#     곱할 수 있는 배열만 주어집니다.
#
# **입출력 예**
#
# ![image.png](attachment:image.png)

# %%
import numpy as np

def solution(arr1, arr2):
    return np.dot(arr1, arr2).tolist()

# %%
print(solution([[1, 4], [3, 2], [4, 1]],[[3, 3], [3, 3]] ))
print(solution([[2, 3, 2], [4, 2, 4], [3, 1, 4]],  [[5, 4, 3], [2, 4, 1], [3, 1, 1]]))
# Out:
# [[15, 15], [15, 15], [15, 15]]
# [[22, 22, 11], [36, 28, 18], [29, 20, 14]]

# %% [markdown]
# **다른 사람 풀이**
#
#     - 코테에서 tensorflow 지원 안되면 numpy 못쓴단다
#     근데 이렇게 쉽게 풀 수 있는건데 굳이 문제를 위한 문제를 풀기 위해서 길게 써야하나?
#     완전 팡션쓰지마세요. 닭잡는칼 소잡는칼 이수준인데... 하지만 그래도 numpy 없이 푸는 방법 익히기
#
#     - 일단 나는 zip을 활용을 잘 못했으니까. zip의 *를 사용해서 unzip을 이용한 풀이 공부하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def productMatrix(A, B):
    return [[sum(a*b for a, b in zip(A_row,B_col)) for B_col in zip(*B)] for A_row in A]

# %%
arr1 = [[2, 3, 2], [4, 2, 4], [3, 1, 4]]
arr2 = [[5, 4, 3], [2, 4, 1], [3, 1, 1]]

for a1_row in arr1:
    print(f"a_row -> {a_row}")
    for a2_col in zip(*arr2):
        print(f"a2_col -> {a2_col}")
        for a1, a2 in zip(a1_row, a2_col):
            print(f"a1, a2 -> {a1}, {a2}")
# Out:
# a_row -> [3, 1, 4]
# a2_col -> (5, 2, 3)
# a1, a2 -> 2, 5
# a1, a2 -> 3, 2
# a1, a2 -> 2, 3
# a2_col -> (4, 4, 1)
# a1, a2 -> 2, 4
# a1, a2 -> 3, 4
# a1, a2 -> 2, 1
# a2_col -> (3, 1, 1)
# a1, a2 -> 2, 3
# a1, a2 -> 3, 1
# a1, a2 -> 2, 1
# a_row -> [3, 1, 4]
# a2_col -> (5, 2, 3)
# a1, a2 -> 4, 5
# a1, a2 -> 2, 2
# a1, a2 -> 4, 3
# a2_col -> (4, 4, 1)
# a1, a2 -> 4, 4
# a1, a2 -> 2, 4
# a1, a2 -> 4, 1
# a2_col -> (3, 1, 1)
# a1, a2 -> 4, 3
# a1, a2 -> 2, 1
# a1, a2 -> 4, 1
# a_row -> [3, 1, 4]
# a2_col -> (5, 2, 3)
# a1, a2 -> 3, 5
# a1, a2 -> 1, 2
# a1, a2 -> 4, 3
# a2_col -> (4, 4, 1)
# a1, a2 -> 3, 4
# a1, a2 -> 1, 4
# a1, a2 -> 4, 1
# a2_col -> (3, 1, 1)
# a1, a2 -> 3, 3
# a1, a2 -> 1, 1
# a1, a2 -> 4, 1
