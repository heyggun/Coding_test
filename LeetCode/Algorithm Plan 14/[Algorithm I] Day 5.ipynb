# %% [markdown]
# # 876. Middle of the Linked List
#
# https://leetcode.com/problems/middle-of-the-linked-list/?envType=study-plan&id=algorithm-i
#
#
# **Description**
#
#     Given the head of a singly linked list, return the middle node of the linked list.
#     If there are two middle nodes, return the second middle node.
#
# **Example**
#
# ![image.png](attachment:image.png)
#
#     Input: head = [1,2,3,4,5]
#     Output: [3,4,5]
#     Explanation: The middle node of the list is node 3.
#
# ![image-2.png](attachment:image-2.png)
#
#     Input: head = [1,2,3,4,5,6]
#     Output: [4,5,6]
#     Explanation: Since the list has two middle nodes with values 3 and 4, we return the second one.
#
# **Constraints**
#
#     The number of nodes in the list is in the range [1, 100].
#     1 <= Node.val <= 100

# %%
# Definition for singly-linked list.

class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def middleNode(self, head):
        n, nHead, half = 0, head, 0
        
        while nHead.next:
            nHead = nHead.next
            n +=1
        
        half = n//2 + n%2
        
        while half>0:
            head = head.next
            half-=1
        
        return head

# %%
sol=  Solution()
head = ListNode([1,2,3,4,5])
print(sol.middleNode(head))
# Out:
# <__main__.ListNode object at 0x0000026458C950D0>

# %%
sol=  Solution()
head = ListNode([1,2,3,4,5,6])
print(sol.middleNode(head))
# Out:
# <__main__.ListNode object at 0x0000026458EC2C10>
# <__main__.ListNode object at 0x0000026458EC2C10>

# %%
class Solution:
    def middleNode(self, head):
        start,end = head, head
        while end and end.next:
            start = start.next
            end = end.next.next
        return start

# %%
sol=  Solution()
head = ListNode([1,2,3,4,5])
print(sol.middleNode(head))
# Out:
# <__main__.ListNode object at 0x0000026458D5D970>

# %%
sol=  Solution()
head = ListNode([1,2,3,4,5,6])
print(sol.middleNode(head))
# Out:
# <__main__.ListNode object at 0x0000026458EDE6A0>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 19. Remove Nth Node From End of List
#
# https://leetcode.com/problems/remove-nth-node-from-end-of-list/?envType=study-plan&id=algorithm-i
#
#
# **Description**
#
#     Given the head of a linked list, remove the nth node from the end of the list and return its head.
#
# **Example**
#
#     Example 1:
#
# ![image.png](attachment:image.png)
#
#     Input: head = [1,2,3,4,5], n = 2
#     Output: [1,2,3,5]
#
#     Example 2:
#     Input: head = [1], n = 1
#     Output: []
#
#     Example 3:
#     Input: head = [1,2], n = 1
#     Output: [1]
#
#
# **Constraints**
#
#     The number of nodes in the list is in the range [1, 100].

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def middleNode(self, head):
        n, nHead, half = 0, head, 0
        while nHead.next:
            nHead = nHead.next
            n +=1

        half = n//2 + n%2

        while half>0:
            head = head.next
            half -= 1
        
        return head

# %%
head = [1,2,3,4,5]
n = 2

tmpList = ListNode(0)
tmpList.next = head
start, end = tmpList, tmpList

for i in range(n):
    start = start.next
    
while start.next!= None:
    start = start.next
    end = end.next
    
end.next = end.next.next

tmpList.next
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [59], in <cell line: 8>()
#       6 start, end = tmpList, tmpList
#       8 for i in range(n):
# ----> 9     start = start.next
#      11 while start.next!= None:
#      12     start = start.next
#
# AttributeError: 'list' object has no attribute 'next'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def removeNthFromEnd(self, head, n):

        tmpList = ListNode(0)
        tmpList.next = head
        start, end = tmpList, tmpList

        for i in range(n):
            start = start.next

        while start.next!=None:
            start = start.next
            end= end.next

        end.next = end.next.next

        return tmpList.next

# %%
# Out:
# [1, 2, 3, 4, 5]
