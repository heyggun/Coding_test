# %% [markdown]
# # LeetCode
#
# 226. Invert Binary Tree
#
# https://leetcode.com/problems/invert-binary-tree/description/
#
#
# **Description**
#
# Given the root of a binary tree, invert the tree, and return its root.
#
# **Examples**
#
#     Example 1:
#
# ![image.png](attachment:image.png)
#
#     Input: root = [4,2,7,1,3,6,9]
#     Output: [4,7,2,9,6,3,1]
#
#     Example 2:
#
# ![image-2.png](attachment:image-2.png)
#
#     Input: root = [2,1,3]
#     Output: [2,3,1]
#
#     Example 3:
#
#     Input: root = []
#     Output: []
#
#
# **Constraints**
#
#     The number of nodes in the tree is in the range [0, 100].
#     -100 <= Node.val <= 100

# %% [markdown]
# ### recusion 1

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
        
class Solution:
    def invertTree(self, root: TreeNode) -> TreeNode:
        if not root:
            return root
        leftval = root.left
        root.left = self.invertTree(root.right)
        root.right = self.inverTree(leftval)
        
        return

# %%
sol = Solution()
print(sol.invertTree(root))
# Out:
# <__main__.TreeNode object at 0x7fb721af8850>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### recusion 2

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

root = TreeNode(val=4, left=TreeNode(2, left=TreeNode(1),right=TreeNode(3)),
               right=TreeNode(7, left=TreeNode(6), right=TreeNode(9)))


class Solution:
    def invertTree(self, root: TreeNode) -> TreeNode:
        if not root:
            return root
        self.invertTree(root.left)
        self.invertTree(root.right)
        root.left, root.right = root.right, root.left
        return root

# %%
sol = Solution()
print(sol.invertTree(root))
# Out:
# <__main__.TreeNode object at 0x7fb71019e7f0>

# %% [markdown]
# ![image.png](attachment:image.png)
