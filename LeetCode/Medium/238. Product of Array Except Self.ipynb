# %% [markdown]
# ## Leetcode
#
# 238. Product of Array Except Self
#
# https://leetcode.com/problems/product-of-array-except-self/
#
#
# **Description**
#
# ![image.png](attachment:98e8cd0e-88c7-48c0-a5b4-edd23217ce57.png)

# %%
from typing import List

# %%
class Solution:
    def productExceptSelf(self, nums: List[int]) -> List[int]:
        ans = [1] * len(nums)
        leftProduct, rightProduct = 1, 1

        for i in range(len(nums)):
            ans[i] *= leftProduct
            leftProduct *= nums[i]

        for i in range(len(nums)-1, -1, -1):
            ans[i] *= rightProduct
            rightProduct *= nums[i]

        return ans

# %%
sol = Solution()
print(sol.productExceptSelf(nums = [1,2,3,4]))
print(sol.productExceptSelf(nums = [-1,1,0,-3,3]))
# Out:
# [24, 12, 8, 6]
# [0, 0, 9, 0, 0]

# %% [markdown]
# ![image.png](attachment:2dfa953b-64b2-4578-994d-63e425e14ec8.png)
