# %% [markdown]
# # Leetcode
#
# 1026. Maximum Difference Between Node and Ancestor
#
# https://leetcode.com/problems/maximum-difference-between-node-and-ancestor/description/
#
# **Description**
#
#     Given the root of a binary tree, find the maximum value v for which there exist different nodes a and b where v = |a.val - b.val| and a is an ancestor of b.
#
#     A node a is an ancestor of b if either: any child of a is equal to b or any child of a is an ancestor of b.
#
#     Example 1:
#
# ![image.png](attachment:image.png)
#
#     Input: root = [8,3,10,1,6,null,14,null,null,4,7,13]
#     Output: 7
#     Explanation: We have various ancestor-node differences, some of which are given below :
#     |8 - 3| = 5
#     |3 - 7| = 4
#     |8 - 1| = 7
#     |10 - 13| = 3
#     Among all possible differences, the maximum value of 7 is obtained by |8 - 1| = 7.
#
#
#     Example 2:
#
# ![image-2.png](attachment:image-2.png)
#
#     Input: root = [1,null,2,null,0,3]
#     Output: 3
#
#
# **Constraints**
#
#     The number of nodes in the tree is in the range [2, 5000].
#     0 <= Node.val <= 10^5

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %%
from typing import Optional

# %%
root = TreeNode(val=8, left=TreeNode(val=3, 
                                        left=TreeNode(val=1, left=None, right=None),
                                        right= TreeNode(val=6, left= TreeNode(val=4, left=None, right= None),
                                                        right= TreeNode(val=7, left=None, right=None))),
                        right=TreeNode(val=10, left=None, right= TreeNode(val= 14,
                                        left=TreeNode(val=13, left=None,right=None),right=None)))

# %%
class Solution:
    def maxAncestorDiff(self, root: Optional[TreeNode]) -> int:
        
        def dfs(node, minVal, maxVal):
            if not node:
                return abs(maxVal-minVal)

            minVal = min(node.val, minVal)
            maxVal = max(node.val, maxVal)

            left = dfs(node.left, minVal, maxVal)
            right = dfs(node.right, minVal, maxVal)

            return max(left, right)

        return dfs(root, float('inf'), float('-inf'))

# %%
sol = Solution()
print(sol.maxAncestorDiff(root))
# Out:
# 7

# %%
root = TreeNode(val=1, left=None, right=TreeNode(val=2, left=None, right=TreeNode(val=0,
                                                    left=TreeNode(val=3, left=None, right=None),
                                                    right=None)))

# %%
sol = Solution()
print(sol.maxAncestorDiff(root))
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:image.png)
