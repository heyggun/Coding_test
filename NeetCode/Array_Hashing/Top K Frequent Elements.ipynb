# %% [markdown]
# Array & Hashing

# %% [markdown]
# Given an integer array nums and an integer k, return the k most frequent elements within the array.
#
# The test cases are generated such that the answer is always unique.
#
# You may return the output in any order.
#
# Example 1:
#
# Input: nums = [1,2,2,3,3,3], k = 2
#
# Output: [2,3]
# Example 2:
#
# Input: nums = [7,7], k = 1
#
# Output: [7]
# Constraints:
#
# 1 <= nums.length <= 10^4.
# -1000 <= nums[i] <= 1000
# 1 <= k <= number of distinct elements in nums.

# %%
nums_1 = [1,2,2,3,3,3]
k_1 = 2

nums_2 = [7,7]
k_2 = 1

# %%
from typing import List

# %%
class Solution:
    def topKFrequent(self, nums: List[int], k: int) -> List[int]:
        ans = []
        seen = {}
        
        for n in nums:
            if n not in seen:
                seen[n] =1
            else:
                seen[n] = seen.get(n,0)+1
                
        while k>0:
            max_key = max(seen, key=seen.get)
            ans.append(max_key)
            del seen[max_key]
            k-=1
            
        return ans

# %%
sol = Solution()
print(sol.topKFrequent(nums_1,k_1))
print(sol.topKFrequent(nums_2,k_2))
# Out:
# [3, 2]
# [7]

# %% [markdown]
#             빈도수를 체크하기 위해서 O(n)은 불가피함.
#             이제 빈도수를 체크했을 때 Top-K를 어떻게 추출할 것인가에 따라 달라짐
#             위에서 사용한 알고리즘은 매번 불필요하게 빈도수가 높은 원소를 찾고 있음
#
#             `while k >0` 루프에서 seen의 크기를 distinct elements = `m`으로 할 때
#             max()가 전체 순회해서 시간복잡도가 O(m)
#             이 방법을 k번 반복하고 있어서 `O(kxm)`
#             최악의 경우 모든 값이 다 다르면 `m=n` 으로 `O(n^2)`

# %% [markdown]
#     Map(Dictionary / HashMap) 에서 빈도수 찾는 방법
#     (1) 정렬 (2) heapq (3)

# %% [markdown]
# 개선

# %%
class Solution:
    def topKFrequent(self, nums: List[int], k: int) -> List[int]:
        
        seen = {}
        freq = [[] for _ in range(len(nums)+1)]
        
        for num in nums:
            seen[num] = seen.get(num,0)+1
            
        for key, val in seen.items():
            freq[val].append(key)
            
        ans = []
        for cnt in range(len(freq)-1, 0,-1):
            for num in freq[cnt]:
                ans.append(num)
                if len(ans)==k:
                    return ans

# %%
sol = Solution()
print(sol.topKFrequent(nums_1,k_1))
print(sol.topKFrequent(nums_2,k_2))
# Out:
# [3, 2]
# [7]
