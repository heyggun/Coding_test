# %% [markdown]
# # lv. 2-5
#
# 타겟 넘버
#
# https://school.programmers.co.kr/learn/courses/30/lessons/43165

# %% [markdown]
# **문제 설명**
#
#     n개의 음이 아닌 정수들이 있습니다. 이 정수들을 순서를 바꾸지 않고 적절히 더하거나 빼서 타겟 넘버를 만들려고 합니다. 예를 들어 [1, 1, 1, 1, 1]로 숫자 3을 만들려면 다음 다섯 방법을 쓸 수 있습니다.
#
#
# ![image.png](attachment:image.png)
#
#     사용할 수 있는 숫자가 담긴 배열 numbers, 타겟 넘버 target이 매개변수로 주어질 때 숫자를 적절히 더하고 빼서 타겟 넘버를 만드는 방법의 수를 return 하도록 solution 함수를 작성해주세요.
#
#
# **제한 사항**
#
#     주어지는 숫자의 개수는 2개 이상 20개 이하입니다.
#     각 숫자는 1 이상 50 이하인 자연수입니다.
#     타겟 넘버는 1 이상 1000 이하인 자연수입니다.
#
#
# **입출력 예**
#
# ![image-2.png](attachment:image-2.png)
#
#
# **입출력 예 설명**
#
#     입출력 예 #1
#     문제 예시와 같습니다.
#
#     입출력 예 #2
#
# ![image-3.png](attachment:image-3.png)
#
#     총 2가지 방법이 있으므로, 2를 return 합니다.

# %%
for i in range(7,-1,-1):
    print(i)
# Out:
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# # lv. 2-6
#
# JadenCase 문자열 만들기
#
#
# https://school.programmers.co.kr/learn/courses/30/lessons/12951

# %%
def solution(s):
    return ''.join(string[0]+string[1:].lower()+' ' if string[0].isdigit()==1 else string+' ' for string in s.title().split()).rstrip()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = "3people unFollowed me"

# %%
s_lst = s.title()
s_lst
# Out:
# '3People Unfollowed Me'

# %%
def solution(s):
    return ' '.join([string[0]+string[1:].lower() if string[0].isdigit() else string[0].upper()+string[1:].lower() for string in s.title().split(' ')])

# %%
print(solution("3people unFollowed me"))
# Out:
# 3people Unfollowed Me

# %%
def solution(s):
    return ' '.join([string.title() if string[0].isalpha()==1 else string[0].upper()+string[1:].lower() for string in s.split(' ')])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(s):
    return ' '.join([string if len(string)==0 else string.title() if string[0].isalpha()==1 else string[0]+string[1:].lower() for string in s.split(' ')])

# %%
print(solution("3people  unFollowed me"))
# Out:
# 3people  Unfollowed Me

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     - 그렇다.. 공백문자가 '연속해서' 나올 수 있다는 것을 고려 했어야 했다.
#      고려 해서 pass. 귀찮아서 list comprehenstion으로 한줄 코딩 비빔 ㅋ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # lv. 2-7
#
# 이진 변환 반복하기
#
#
# https://school.programmers.co.kr/learn/courses/30/lessons/70129

# %% [markdown]
# **문제 설명**
#
#     0과 1로 이루어진 어떤 문자열 x에 대한 이진 변환을 다음과 같이 정의합니다.
#
#     x의 모든 0을 제거합니다.
#     x의 길이를 c라고 하면, x를 "c를 2진법으로 표현한 문자열"로 바꿉니다.
#     예를 들어, x = "0111010"이라면, x에 이진 변환을 가하면 x = "0111010" -> "1111" -> "100" 이 됩니다.
#
#     0과 1로 이루어진 문자열 s가 매개변수로 주어집니다. s가 "1"이 될 때까지 계속해서 s에 이진 변환을 가했을 때, 이진 변환의 횟수와 변환 과정에서 제거된 모든 0의 개수를 각각 배열에 담아 return 하도록 solution 함수를 완성해주세요.
#
# **제한 사항**
#
#     s의 길이는 1 이상 150,000 이하입니다.
#     s에는 '1'이 최소 하나 이상 포함되어 있습니다.
#
#
# **입출력 예**
#
# ![image.png](attachment:image.png)
#
#
# **입출력 예 설명**
#
#
#     입출력 예 #1
#     "110010101001"이 "1"이 될 때까지 이진 변환을 가하는 과정은 다음과 같습니다.
#
# ![image-2.png](attachment:image-2.png)
#
#     3번의 이진 변환을 하는 동안 8개의 0을 제거했으므로, [3,8]을 return 해야 합니다.
#
#     입출력 예 #2
#     "01110"이 "1"이 될 때까지 이진 변환을 가하는 과정은 다음과 같습니다.
#
# ![image-3.png](attachment:image-3.png)
#
#     3번의 이진 변환을 하는 동안 3개의 0을 제거했으므로, [3,3]을 return 해야 합니다.
#
#
#     입출력 예 #3
#     "1111111"이 "1"이 될 때까지 이진 변환을 가하는 과정은 다음과 같습니다.
#
# ![image-4.png](attachment:image-4.png)
#
#     4번의 이진 변환을 하는 동안 1개의 0을 제거했으므로, [4,1]을 return 해야 합니다.

# %%
def solution(s):
    zero_cnt = 0
    binary_cnt = 0
    
    while int(s)!=1:
        zero_cnt += s.count('0')
        s = bin(len(s.replace('0','')))[2:]
        binary_cnt +=1
    
    answer = [binary_cnt, zero_cnt]
    
    return answer

# %%
print(solution("110010101001"))
print(solution("01110"))
print(solution("1111111"))
# Out:
# [3, 8]
# [3, 3]
# [4, 1]
