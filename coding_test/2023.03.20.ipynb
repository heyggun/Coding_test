# %% [markdown]
# # LV 2.
#
# 방문 길이
#
# https://school.programmers.co.kr/learn/courses/30/lessons/49994

# %% [markdown]
# **문제 설명**
#
#     게임 캐릭터를 4가지 명령어를 통해 움직이려 합니다. 명령어는 다음과 같습니다.
#
#     U: 위쪽으로 한 칸 가기
#     D: 아래쪽으로 한 칸 가기
#     R: 오른쪽으로 한 칸 가기
#     L: 왼쪽으로 한 칸 가기
#
#     캐릭터는 좌표평면의 (0, 0) 위치에서 시작합니다. 좌표평면의 경계는 왼쪽 위(-5, 5), 왼쪽 아래(-5, -5), 오른쪽 위(5, 5), 오른쪽 아래(5, -5)로 이루어져 있습니다.
#
# ![image.png](attachment:image.png)
#
#     예를 들어, "ULURRDLLU"로 명령했다면
#
# ![image-2.png](attachment:image-2.png)
#
#     1번 명령어부터 7번 명령어까지 다음과 같이 움직입니다.
#
# ![image-3.png](attachment:image-3.png)
#
#     8번 명령어부터 9번 명령어까지 다음과 같이 움직입니다.
#
# ![image-4.png](attachment:image-4.png)
#
#     이때, 우리는 게임 캐릭터가 지나간 길 중 캐릭터가 처음 걸어본 길의 길이를 구하려고 합니다. 예를 들어 위의 예시에서 게임 캐릭터가 움직인 길이는 9이지만, 캐릭터가 처음 걸어본 길의 길이는 7이 됩니다. (8, 9번 명령어에서 움직인 길은 2, 3번 명령어에서 이미 거쳐 간 길입니다)
#
#     단, 좌표평면의 경계를 넘어가는 명령어는 무시합니다.
#     예를 들어, "LULLLLLLU"로 명령했다면
#
# ![image-5.png](attachment:image-5.png)
#
#     1번 명령어부터 6번 명령어대로 움직인 후, 7, 8번 명령어는 무시합니다. 다시 9번 명령어대로 움직입니다.
#
# ![image-6.png](attachment:image-6.png)
#
#     이때 캐릭터가 처음 걸어본 길의 길이는 7이 됩니다.
#     명령어가 매개변수 dirs로 주어질 때, 게임 캐릭터가 처음 걸어본 길의 길이를 구하여 return 하는 solution 함수를 완성해 주세요.
#
# **제한사항**
#
#     dirs는 string형으로 주어지며, 'U', 'D', 'R', 'L' 이외에 문자는 주어지지 않습니다.
#     dirs의 길이는 500 이하의 자연수입니다.
#
# **입출력 예**
#
# ![image-7.png](attachment:image-7.png)
#
# **입출력 예 설명**
#
#     입출력 예 설명
#     입출력 예 #1
#     문제의 예시와 같습니다.
#
#     입출력 예 #2
#     문제의 예시와 같습니다.

# %%
def solution(dirs):
    position = {'L':(-1,0), 'R':(1,0), 'U':(0,1), 'D':(0,-1)}
    x,y = 0,0
    moving_set = set()
    
    for d in dirs:
        moving_x, moving_y = x+position[d][0], y+position[d][1]
        
        if -5<=moving_x<=5 and -5<=moving_y<=5:
            moving_set.add(((x,y), (moving_x,moving_y)))
            moving_set.add(((moving_x, moving_y), (x,y)))
            x,y = moving_x, moving_y
        
    return len(moving_set)//2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dirs ="LULLLLLLU"

position = {'L':(-1,0), 'R':(1,0), 'U':(0,1), 'D':(0,-1)}
start_x, start_y = 0,0
moving = set()

for d in dirs:
    if -5<=start_x+position[d][0]<=5 and -5<=start_y+position[d][1]<=5:
        moving_start_x = start_x + position[d][0]
        moving_start_y = start_y + position[d][1]
        moving.add((start_x,start_y, moving_start_x,moving_start_y))
        start_x, start_y = moving_start_x, moving_start_y
        
    else:
        pass
    
len(moving)
# Out:
# 7

# %%
def solution(dirs):
    position = {'L':(-1,0), 'R':(1,0), 'U':(0,1), 'D':(0,-1)}
    start_x, start_y = 0,0
    moving = []

    for d in dirs:
        if -5<=start_x+position[d][0]<=5 and -5<=start_y+position[d][1]<=5:
            moving_start_x = start_x + position[d][0]
            moving_start_y = start_y + position[d][1]
            moving.append((start_x,start_y, moving_start_x,moving_start_y))
            start_x, start_y = moving_start_x, moving_start_y

        else:
            pass

    return len(set(moving))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dirs = "ULURRDLLU"

position = {'L':(-1,0), 'R':(1,0), 'U':(0,1), 'D':(0,-1)}
x, y = 0,0
moving_set = set()

for d in dirs:
    print(f"d -> {d}")
    moving_x, moving_y = x+position[d][0], y+position[d][1]
    if -5<=moving_x<=5 and -5<=moving_y<=5:
        moving_set.add(((x,y),(moving_x,moving_y)))
        moving_set.add(((moving_x,moving_y),(x,y)))
        x,y = moving_x, moving_y
        
len(moving_set)//2
# Out:
# d -> U
# d -> L
# d -> U
# d -> R
# d -> R
# d -> D
# d -> L
# d -> L
# d -> U
# 7
