# %% [markdown]
# # LV2.
#
# 카펫
#
# https://school.programmers.co.kr/learn/courses/30/lessons/42842

# %% [markdown]
# **문제 설명**
#
#     Leo는 카펫을 사러 갔다가 아래 그림과 같이 중앙에는 노란색으로 칠해져 있고 테두리 1줄은 갈색으로 칠해져 있는 격자 모양 카펫을 봤습니다.
#
#
# ![image.png](attachment:image.png)
#
#     Leo는 집으로 돌아와서 아까 본 카펫의 노란색과 갈색으로 색칠된 격자의 개수는 기억했지만, 전체 카펫의 크기는 기억하지 못했습니다.
#
#     Leo가 본 카펫에서 갈색 격자의 수 brown, 노란색 격자의 수 yellow가 매개변수로 주어질 때 카펫의 가로, 세로 크기를 순서대로 배열에 담아 return 하도록 solution 함수를 작성해주세요.
#
#
# **제한사항**
#
#     갈색 격자의 수 brown은 8 이상 5,000 이하인 자연수입니다.
#     노란색 격자의 수 yellow는 1 이상 2,000,000 이하인 자연수입니다.
#     카펫의 가로 길이는 세로 길이와 같거나, 세로 길이보다 깁니다.
#
#
# **입출력 예**
#
# ![image-2.png](attachment:image-2.png)
#
#
#     ※ 공지 - 2020년 2월 3일 테스트케이스가 추가되었습니다.
#     ※ 공지 - 2020년 5월 11일 웹접근성을 고려하여 빨간색을 노란색으로 수정하였습니다.

# %%
def solution(brown, yellow):
    answer = []
    yellow_w, yellow_h = 0,0
    
    for i in range(1, yellow+1):
        if yellow%i==0:
            yellow_w  = int(yellow/i)
            yellow_h = i
            
            if (yellow_w*2) + (yellow_h*2) +4 == brown:
                answer.append(yellow_w+2)
                answer.append(yellow_h+2)
                break
                
    sorted(answer, reverse=True)
    return answer

# %%
print(solution(10,2))
print(solution(8,1))
print(solution(24,24))
# Out:
# [4, 3]
# [3, 3]
# [8, 6]

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
#     수능 문제 푸는 줄.. 알았네... 노가다로 그려봤음 (그래봤자 지쳐서 5개까지 밖에)
#     하지만 나는 규칙을 찾지 못했다..
#     나는 순식간에 감이 왔다.. 이건 내가 답을 보지 않고서야.. 영영 못푸는 뭔가 있을 거라고
#     그래서 찾아봄

# %% [markdown]
#     - (yellow의 가로*2) + (yellow의 세로*2) +4 = 갈색 겨자수가 같으면 된다는 공식 발견..
#     - 쉽게 가로의 길이는 주어진 yellow의 에서 2를 더하면 된다는 것을 파악할 수는 있다.
#     그러나,, 저 +4 해괴망측한건.. 어디서 오는건지.. 생각해봤는데
#     위의 그림에서 보다시피 가로 길이 +2, 세로 길이 +2 를 하고 남은 yellow를 감싸앉는 나머지 갈색 겨자수는 기가막히게 대각에 남는 4개가 된다.. 이런거 였군..

# %% [markdown]
#     - 고로, yellow의 개수를 for문을을 통해 돌면서,
#     brown 에 맞는 yello의 세로, 가로 길이를 구해 최종 카펫의 길이를 구한다!

# %%
yellow,brown = 24,24

yello_w, yellow_h = 0,0
answer = []

for i in range(1, yellow+1):
    if yellow %i ==0:
        yellow_w = int(yellow/i)
        yellow_h = i
        
        if yellow_w*2 + yellow_h*2 +4==brown:
            answer.append(yellow_w+2)
            answer.append(yellow_h+2)
            break
            
sorted(answer, reverse=True)
# Out:
# [8, 6]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **다른사람 풀이**
#
#     저 풀이가 다른 사람 풀이^*^ 이제 외웠으니까 내풀이
