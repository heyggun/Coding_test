# %% [markdown]
# # LV 2.
#
# 숫자의 표현
#
# https://school.programmers.co.kr/learn/courses/30/lessons/12924

# %% [markdown]
# **문제 설명**
#
#     Finn은 요즘 수학공부에 빠져 있습니다. 수학 공부를 하던 Finn은 자연수 n을 연속한 자연수들로 표현 하는 방법이 여러개라는 사실을 알게 되었습니다. 예를들어 15는 다음과 같이 4가지로 표현 할 수 있습니다.
#
#     1 + 2 + 3 + 4 + 5 = 15
#     4 + 5 + 6 = 15
#     7 + 8 = 15
#     15 = 15
#     자연수 n이 매개변수로 주어질 때, 연속된 자연수들로 n을 표현하는 방법의 수를 return하는 solution를 완성해주세요.
#
# **제한사항**
#
#     n은 10,000 이하의 자연수 입니다.
#
# **입출력 예**
#
# ![image.png](attachment:image.png)
#
#
# **입출력 예 설명**
#
#     입출력 예#1
#     문제의 예시와 같습니다.
#
#     ※ 공지 - 2022년 3월 11일 테스트케이스가 추가되었습니다.

# %%
def solution(n):
    answer = 0
    cnt = 0
    n_lst = [idx for idx in range(n+1)]
    
    for i in range(1, len(n_lst)):
        cnt = 0
        for j in range(i, len(n_lst)):
            cnt += j
            if cnt <= 15 and cnt ==15:
                answer +=1
                cnt = 0
                break
            if cnt > 15:
                cnt = 0
                break
    
    return answer

# %%
print(solution(15))
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     - 다른 느낌적인 느낌으로 풀어야 하는 구나?

# %%
def solution(n):
    answer = 0
    for i in range(1, n+1):
        tmp = i
        
        while True:
            if i==n:
                answer +=1
                break      
                
            elif i>15:
                break
            
            tmp+=1
            i+=tmp
        
    return answer

# %%
print(solution(15))
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     -> 이게 외않되? 이러고 있었는데 n 값을 15로 줘버린거 실화냐 n 으로 줘야지

# %%
def solution(n):
    answer = 0
    for i in range(1, n+1):
        tmp = i
        
        while True:
            if i==n:
                answer +=1
                break      
                
            elif i>n:
                break
            
            tmp+=1
            i+=tmp
        
    return answer

# %% [markdown]
#      - n을 15로 지정해놓은거 보고 로직 왜 이상하지 이러면서 30분 허비함 ... 나는 삼류
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **다른 사람 풀이**
#
# ![image.png](attachment:image.png)

# %% [markdown]
#     - 수학 공식을 이용해서 풀어버린... 도랏..

# %%
lst = []

for i in range(1, 15+1, 2):
    print(i)
    
    if 15%i ==0:
        lst.append(i)
        
lst
# Out:
# 1
# 3
# 5
# 7
# 9
# 11
# 13
# 15
# [1, 3, 5, 15]

# %% [markdown]
#     - 이런 수학공식이 있나보다.. 수학자야? 이해를 못해서 찾아봄
#
# https://gkalstn000.github.io/2021/01/21/%EC%88%AB%EC%9E%90%EC%9D%98-%ED%91%9C%ED%98%84/

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
#     - 무사와요 무사와요.. 제 코드로 할래요
