# %% [markdown]
# # LV 3.
#
# 네트워크
#
# https://school.programmers.co.kr/learn/courses/30/lessons/43162

# %% [markdown]
# **문제 설명**
#
#     네트워크란 컴퓨터 상호 간에 정보를 교환할 수 있도록 연결된 형태를 의미합니다. 예를 들어, 컴퓨터 A와 컴퓨터 B가 직접적으로 연결되어있고, 컴퓨터 B와 컴퓨터 C가 직접적으로 연결되어 있을 때 컴퓨터 A와 컴퓨터 C도 간접적으로 연결되어 정보를 교환할 수 있습니다. 따라서 컴퓨터 A, B, C는 모두 같은 네트워크 상에 있다고 할 수 있습니다.
#     컴퓨터의 개수 n, 연결에 대한 정보가 담긴 2차원 배열 computers가 매개변수로 주어질 때, 네트워크의 개수를 return 하도록 solution 함수를 작성하시오.
#
# **제한사항**
#
#     컴퓨터의 개수 n은 1 이상 200 이하인 자연수입니다.
#     각 컴퓨터는 0부터 n-1인 정수로 표현합니다.
#     i번 컴퓨터와 j번 컴퓨터가 연결되어 있으면 computers[i][j]를 1로 표현합니다.
#     computer[i][i]는 항상 1입니다.
#
#
# **입출력 예**
#
# ![image.png](attachment:image.png)
#
#
# **입출력 예 설명**
#
#     예제 #1
#     아래와 같이 2개의 네트워크가 있습니다.
#
# ![image-2.png](attachment:image-2.png)
#
#
#     예제 #2
#     아래와 같이 1개의 네트워크가 있습니다.
#
# ![image-3.png](attachment:image-3.png)

# %%
def solution(n, computers):
    answer = 0
    return answer

# %%
def solution(n, computers):
    answer = 0
    visited = [False for _ in range(n)]
    for com in range(n):
        if visited[com] == False:
            dfs(n, computers, com, visited)
            answer += 1
    return answer

def dfs(n, computers, com, visited):
    visited[com] = True
    for con in range(n):
        if con != com and computers[com][con] == 1:
            if visited[con] == False:
                dfs(n, computers, con, visited)

# %%
print(solution(3, [[1, 1, 0], [1, 1, 1], [0, 1, 1]]))
# Out:
# 1

# %%
computers = [[1, 1, 0], [1, 1, 1], [0, 1, 1]]
n= 3

answer = 0
visited = [False for i in range(n)]
print(f"origin visited-> {visited}")

for com in range(n):
    print(f"(1) com -> {com}")
    if visited[com] == False:
        print(f"visited[com] -> {visited[com]}")
        print(f"DFS 들어가기전 n->{n}, computers->{computers}, com->{com}, visited->{visited}")
        DFS(n, computers, com, visited)
        answer +=1 
    answer
# Out:
# origin visited-> [False, False, False]
# (1) com -> 0
# visited[com] -> False
# DFS 들어가기전 n->3, computers->[[1, 1, 0], [1, 1, 1], [0, 1, 1]], com->0, visited->[False, False, False]
# (1) com -> 1
# (1) com -> 2

# %%
visited[0] = True
    for connect in range(n):
        print(f" n->{n}, connect -> {connect}")
        if connect != com and computers[com][connect] ==1:
            if visited[connect] ==False:
                prin
                DFS(n, computers, connect, visited)

# %%
def solution(n, computers):
    answer = 0
    visited = [False for i in range(n)]
    print(f" solution의 visited -> {visited}")
    for com in range(n):
        print(f"solution의 n과 com -> {n} : {com}")
        if visited[com] == False:
            print(f"DFS 에 들어가기전 n -> {n}, computers -> {computers}, com ->{com}, visited -> {visited}")
            DFS(n, computers, com, visited)
            answer += 1 #DFS로 최대한 컴퓨터들을 방문하고 빠져나오게 되면 그것이 하나의 네트워크.
    return answer

def DFS(n, computers, com, visited):
    visited[com] = True
    print(f" DFS의 visited -> {visited}")
    for connect in range(n):
        print(f"DFS의 n : {n} conncet:  {connect}, com -> {com}")
        if connect != com and computers[com][connect] == 1: #연결된 컴퓨터
            if visited[connect] == False:
                print(f" visited[connect]==False 일때의 n-{n}, computers->{computers}, connect -> {connect},visited -> {visited}")
                DFS(n, computers, connect, visited)

# %%
print(solution(3,[[1, 1, 0], [1, 1, 1], [0, 1, 1]]))
# Out:
#  solution의 visited -> [False, False, False]
# solution의 n과 com -> 3 : 0
# DFS 에 들어가기전 n -> 3, computers -> [[1, 1, 0], [1, 1, 1], [0, 1, 1]], com ->0, visited -> [False, False, False]
#  DFS의 visited -> [True, False, False]
# DFS의 n : 3 conncet:  0, com -> 0
# DFS의 n : 3 conncet:  1, com -> 0
#  visited[connect]==False 일때의 n-3, computers->[[1, 1, 0], [1, 1, 1], [0, 1, 1]], connect -> 1,visited -> [True, False, False]
#  DFS의 visited -> [True, True, False]
# DFS의 n : 3 conncet:  0, com -> 1
# DFS의 n : 3 conncet:  1, com -> 1
# DFS의 n : 3 conncet:  2, com -> 1
#  visited[connect]==False 일때의 n-3, computers->[[1, 1, 0], [1, 1, 1], [0, 1, 1]], connect -> 2,visited -> [True, True, False]
#  DFS의 visited -> [True, True, True]
# DFS의 n : 3 conncet:  0, com -> 2
# DFS의 n : 3 conncet:  1, com -> 2
# DFS의 n : 3 conncet:  2, com -> 2
# DFS의 n : 3 conncet:  2, com -> 0
# solution의 n과 com -> 3 : 1
# solution의 n과 com -> 3 : 2
# 1

# %%
print(solution(3, [[1, 1, 0], [1, 1, 0], [0, 0, 1]]))
# Out:
#  solution의 visited -> [False, False, False]
# solution의 n과 com -> 3 : 0
# DFS 에 들어가기전 n -> 3, computers -> [[1, 1, 0], [1, 1, 0], [0, 0, 1]], com ->0, visited -> [False, False, False]
#  DFS의 visited -> [True, False, False]
# DFS의 n : 3 conncet:  0
# DFS의 connect : 0, com : 0
# DFS의 n : 3 conncet:  1
# DFS의 connect : 1, com : 0
#  visited[connect]==False 일때의 n-3, computers->[[1, 1, 0], [1, 1, 0], [0, 0, 1]], connect -> 1,visited -> [True, False, False]
#  DFS의 visited -> [True, True, False]
# DFS의 n : 3 conncet:  0
# DFS의 connect : 0, com : 1
# DFS의 n : 3 conncet:  1
# DFS의 connect : 1, com : 1
# DFS의 n : 3 conncet:  2
# DFS의 connect : 2, com : 1
# DFS의 n : 3 conncet:  2
# DFS의 connect : 2, com : 0
# solution의 n과 com -> 3 : 1
# solution의 n과 com -> 3 : 2
# DFS 에 들어가기전 n -> 3, computers -> [[1, 1, 0], [1, 1, 0], [0, 0, 1]], com ->2, visited -> [True, True, False]
#  DFS의 visited -> [True, True, True]
# DFS의 n : 3 conncet:  0
# DFS의 connect : 0, com : 2
# DFS의 n : 3 conncet:  1
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **다른 사람 풀이**
#
# ![image.png](attachment:image.png)

# %% [markdown]
#     - 플루이드-워셜 알고리즘인데.. 그게 뭔데.. 그거 어떻게 하는건데
#
# https://chanhuiseok.github.io/posts/algo-50/
#
#
#     골 때리네..
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
