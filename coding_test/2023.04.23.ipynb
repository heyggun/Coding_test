# %% [markdown]
# # LV 0.
#
# 공배수
#
# https://school.programmers.co.kr/learn/courses/30/lessons/181936?language=python3

# %% [markdown]
# **문제 설명**
#
#     정수 number와 n, m이 주어집니다. number가 n의 배수이면서 m의 배수이면 1을 아니라면 0을 return하도록 solution 함수를 완성해주세요.
#
#
# **제한사항**
#
#     10 ≤ number ≤ 100
#     2 ≤ n, m < 10
#
#
# **입출력 예**
#
# ![](https://velog.velcdn.com/images/heyggun/post/a547225b-739e-4614-ac8a-9cd461b741ac/image.png)
#
#
# **입출력 예 설명**
#
#     입출력 예 #1
#     60은 2의 배수이면서 3의 배수이기 때문에 1을 return합니다.
#
#     입출력 예 #2
#     55는 5의 배수이지만 10의 배수가 아니기 때문에 0을 return합니다.

# %%
def solution(number, n, m):
    return 1 if (number%n==0) & (number%m==0) else 0

# %%
print(solution(60,2,3))
print(solution(55,10,5))
# Out:
# 1
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # LV 0.
#
# 대문자로 바꾸기
#
# https://school.programmers.co.kr/learn/courses/30/lessons/181877

# %% [markdown]
# **문제 설명**
#
#     알파벳으로 이루어진 문자열 myString이 주어집니다. 모든 알파벳을 대문자로 변환하여 return 하는 solution 함수를 완성해 주세요.
#
# **제한사항**
#
#     1 ≤ myString의 길이 ≤ 100,000
#     myString은 알파벳으로 이루어진 문자열입니다.
#
# **입출력 예**
#
# ![](https://velog.velcdn.com/images/heyggun/post/9429a96e-82d8-41c5-ab1a-bf06a815cf75/image.png)

# %%
def solution(myString):
    return myString.upper()

# %%
print(solution('aBcDeFg'))
print(solution('AAA'))
# Out:
# ABCDEFG
# AAA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # LV 0.
#
# n 번째 원소까지
#
# https://school.programmers.co.kr/learn/courses/30/lessons/181889

# %% [markdown]
# **문제 설명**
#
#     정수 리스트 num_list와 정수 n이 주어질 때, num_list의 첫 번째 원소부터 n 번째 원소까지의 모든 원소를 담은 리스트를 return하도록 solution 함수를 완성해주세요.
#
# **제한사항**
#
#     2 ≤ num_list의 길이 ≤ 30
#     1 ≤ num_list의 원소 ≤ 9
#     1 ≤ n ≤ num_list의 길이 ___
#
# **입출력 예**
#
# ![](https://velog.velcdn.com/images/heyggun/post/7b890046-6a69-4fa3-a718-19dd50614eba/image.png)
#
#
# **입출력 에 설명**
#
#     입출력 예 #1
#     [2, 1, 6]의 첫 번째 원소부터 첫 번째 원소까지의 모든 원소는 [2]입니다.
#
#     입출력 예 #2
#     [5, 2, 1, 7, 5]의 첫 번째 원소부터 세 번째 원소까지의 모든 원소는 [5, 2, 1]입니다.

# %%
def solution(num_list, n):
    return num_list[:n]

# %%
print(solution([2,1,6],1))
print(solution([5,2,1,7,5],3))
# Out:
# [2]
# [5, 2, 1]

# %% [markdown]
# ![](https://velog.velcdn.com/images/heyggun/post/1e5f87f5-68a1-469e-be01-4ccea9e44edb/image.png)

# %% [markdown]
# # LV 0.
#
# 부분 문자열인지 확인하기
#
# https://school.programmers.co.kr/learn/courses/30/lessons/181843

# %% [markdown]
# **문제 설명**
#
#     부분 문자열이란 문자열에서 연속된 일부분에 해당하는 문자열을 의미합니다. 예를 들어, 문자열 "ana", "ban", "anana", "banana", "n"는 모두 문자열 "banana"의 부분 문자열이지만, "aaa", "bnana", "wxyz"는 모두 "banana"의 부분 문자열이 아닙니다.
#     문자열 my_string과 target이 매개변수로 주어질 때, target이 문자열 my_string의 부분 문자열이라면 1을, 아니라면 0을 return 하는 solution 함수를 작성해 주세요.
#
# **제한사항**
#
#     1 ≤ my_string의 길이 ≤ 100
#     my_string은 영소문자로만 이루어져 있습니다.
#     1 ≤ target의 길이 ≤ 100
#     target은 영소문자로만 이루어져 있습니다.
#
# **입출력 예**
# ![](https://velog.velcdn.com/images/heyggun/post/712ab484-dfff-477c-b268-e57e8f3d3506/image.png)
#
# **입출력 예 설명**
#
#     입출력 예 #1
#     문제 설명과 같습니다.
#
#     입출력 예 #2
#     문제 설명과 같습니다.

# %%
def solution(my_string, target):
    
    try:
        firstStr = target[0]
        strLen = len(target)
        check = my_string[my_string.index(firstStr):my_string.index(firstStr)+len(target)]
        try:
            if check==target:
                answer= 1
            else:
                answer= 0
        except:
            answer =0
            
            

    except:
        answer = 0

    return answer

# %%
print(solution('banana','ana'))
print(solution('banana','wxyz'))
# Out:
# 1
# 0

# %%
my_string, target = 'banana', 'ana'

if my_string.find(target):
    firstStr = target[0]
    strLen = len(target)
    check = my_string[my_string.index(firstStr):my_string.index(firstStr)+len(target)]
    if check==target:
        answer= 1
    else:
        0
    
else:
    answer = 0

answer
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def solution(my_string, target):
    answer= 0
    if my_string.find(target[0]) != -1:
        for idx,string in enumerate(my_string):
            if string==target[0]:
                if my_string[idx:idx+len(target)]==target:
                    return 1    
    else:
        return 0
    return answer

# %%
print(solution('banana','ana'))
print(solution('banana','wxyz'))
# Out:
# 1
# 0

# %%
def solution(my_string, target):
    if target in my_string: return 1
    return 0

# %%
print(solution('banana','ana'))
print(solution('banana','wxyz'))
# Out:
# 1
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # LV 0.
#
# 정수 찾기
#
# https://school.programmers.co.kr/learn/courses/30/lessons/181840

# %% [markdown]
# **문제 설명**
#
#     정수 리스트 num_list와 찾으려는 정수 n이 주어질 때, num_list안에 n이 있으면 1을 없으면 0을 return하도록 solution 함수를 완성해주세요.
#
# **제한사항**
#
#     3 ≤ num_list의 길이 ≤ 100
#     1 ≤ num_list의 원소 ≤ 100
#     1 ≤ n ≤ 100
#
#
# **입출력 예**
#
# ![](https://velog.velcdn.com/images/heyggun/post/7a6ab40c-a7fd-4337-b25e-74d2c58d1085/image.png)
#
#
# **입출력 예 설명**
#
#     입출력 예 #1
#     [1, 2, 3, 4, 5] 안에 3이 있으므로 1을 return합니다.
#
#     입출력 예 #2
#     [15, 98, 23, 2, 15] 안에 20이 없으므로 0을 return합니다.

# %%
def solution(num_list, n):
    return 1 if n in num_list else 0

# %%
print(solution([1,2,3,4,5],3))
print(solution([15,98,23,2,15],20))
# Out:
# 1
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # LV 0.
#
# 문자열로 변환
#
# https://school.programmers.co.kr/learn/courses/30/lessons/181845

# %% [markdown]
# **문제 설명**
#
#     정수 n이 주어질 때, n을 문자열로 변환하여 return하도록 solution 함수를 완성해주세요.
#
# **제한사항**
#
#     1 ≤ n ≤ 10000
#
# **입출력 예**
#
# ![](https://velog.velcdn.com/images/heyggun/post/c8ff8e91-b42b-4220-87eb-35d1ca6207e8/image.png)
#
# **입출력 예 설명**
#
#     입출력 예 #1
#     123을 문자열로 변환한 "123"을 return합니다.
#
#     입출력 예 #2
#     2573을 문자열로 변환한 "2573"을 return합니다.

# %%
def solution(n):
    return str(n)

# %%
print(solution(123))
print(solution(2573))
# Out:
# 123
# 2573

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lv 0.
#
# 소문자로 바꾸기
#
# https://school.programmers.co.kr/learn/courses/30/lessons/181876

# %% [markdown]
# **문제 설명**
#
#     알파벳으로 이루어진 문자열 myString이 주어집니다. 모든 알파벳을 소문자로 변환하여 return 하는 solution 함수를 완성해 주세요.
#
#
# **제한사항**
#
#     1 ≤ myString의 길이 ≤ 100,000
#     myString은 알파벳으로 이루어진 문자열입니다.
#
# **입출력 예**
#
# ![](https://velog.velcdn.com/images/heyggun/post/4143a8e9-90a4-4817-9b57-46a40620f3b2/image.png)

# %%
def solution(myString):
    return myString.lower()

# %%
print(solution('aBcDeFg'))
print(solution('aaa'))
# Out:
# abcdefg
# aaa

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # LV 0.
#
#
# 문자열을 정수로 변환하기
#
# https://school.programmers.co.kr/learn/courses/30/lessons/181848

# %% [markdown]
# **문제 설명**
#
#     숫자로만 이루어진 문자열 n_str이 주어질 때, n_str을 정수로 변환하여 return하도록 solution 함수를 완성해주세요.
#
# **제한사항**
#
#     1 ≤ n_str ≤ 5
#     n_str은 0부터 9까지의 정수 문자로만 이루어져 있습니다.
#
# **입출력 예**
#
# ![](https://velog.velcdn.com/images/heyggun/post/5f9eeaef-ae32-42ae-bbae-d55103796d1e/image.png)
#
#
# **입출력 예 설명**
#
#     입출력 예 #1
#     "10"을 정수로 바꾸면 10입니다.
#
#     입출력 예 #2
#     "8542"를 정수로 바꾸면 8542입니다.

# %%
def solution(n_str):
    return n_str.lower()

# %%
print(solution('10'))
print(solution('8542'))
# Out:
# 10
# 8542

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lv 0.
#
# 문자열 정수의 합
#
# https://school.programmers.co.kr/learn/courses/30/lessons/181849

# %% [markdown]
# **문제 설명**
#
#     한 자리 정수로 이루어진 문자열 num_str이 주어질 때, 각 자리수의 합을 return하도록 solution 함수를 완성해주세요.
#
# **제한사항**
#
#     3 ≤ num_str ≤ 100
#
#
# **입출력 예**
#
# ![](https://velog.velcdn.com/images/heyggun/post/31213fe5-9e97-4e58-9e8f-8cdff122da4f/image.png)
#
#
# **입출력 예 설명**
#
#     입출력 예 #1
#     문자열 안의 모든 숫자를 더하면 45가 됩니다.
#
#     입출력 예 #2
#     문자열 안의 모든 숫자를 더하면 1이 됩니다.

# %%
def solution(num_str):
    return sum(list(map(int, num_str)))

# %%
print(solution('123456789'))
print(solution("1000000"))
# Out:
# 45
# 1

# %%
num = "123456789"

sum(list(map(int, list(num))))
# Out:
# 45

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # LV 0.
#
# 정수 부분
#
# https://school.programmers.co.kr/learn/courses/30/lessons/181850

# %% [markdown]
# **문제 설명**
#
#     실수 flo가 매개 변수로 주어질 때, flo의 정수 부분을 return하도록 solution 함수를 완성해주세요.
#
#
# **제한사항**
#
#     0 ≤ flo ≤ 100
#
#
# **입출력 예**
#
# ![](https://velog.velcdn.com/images/heyggun/post/5ad7429d-ff03-46b0-b907-9c7a0554ce79/image.png)
#
#
#
# **입출력 예 설명**
#
#     입출력 예 #1
#     1.42의 정수 부분은 1입니다.
#
#     입출력 예 #2
#     69.32의 정수 부분은 69입니다.

# %%
def solution(flo):
    return int(flo)

# %%
print(solution(1.42))
print(solution(69.32))
# Out:
# 1
# 69

# %% [markdown]
# ![image.png](attachment:image.png)
