# %% [markdown]
# # LV 2.
#
# 가장 큰 수
#
# https://school.programmers.co.kr/learn/courses/30/lessons/42746?language=python3

# %% [markdown]
# **문제 설명**
#
#     0 또는 양의 정수가 주어졌을 때, 정수를 이어 붙여 만들 수 있는 가장 큰 수를 알아내 주세요.
#     예를 들어, 주어진 정수가 [6, 10, 2]라면 [6102, 6210, 1062, 1026, 2610, 2106]를 만들 수 있고, 이중 가장 큰 수는 6210입니다.
#     0 또는 양의 정수가 담긴 배열 numbers가 매개변수로 주어질 때, 순서를 재배치하여 만들 수 있는 가장 큰 수를 문자열로 바꾸어 return 하도록 solution 함수를 작성해주세요.
#
# **제한 사항**
#
#     numbers의 길이는 1 이상 100,000 이하입니다.
#     numbers의 원소는 0 이상 1,000 이하입니다.
#     정답이 너무 클 수 있으니 문자열로 바꾸어 return 합니다.
#
# **입출력 예**
#
# ![image.png](attachment:image.png)
#
#     ※ 공지 - 2021년 10월 20일 테스트케이스가 추가되었습니다.

# %%
from itertools import permutations

def solution(numbers):
    pers = permutations(numbers,len(numbers))
    
    return str(max([int(''.join(map(str,idx))) for idx in list(map(list, list(pers)))]))

# %%
print(solution([6,10,2]))
print(solution([3,30,34,5,9]))
# Out:
# 6210
# 9534330

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(numbers):
    num_lst = list(map(str, list(numbers)))
    num_lst.sort(key=lambda x: x*3, reverse =True)
    
    return str(int(''.join(num_lst)))

# %%
print(solution([6,10,2]))
print(solution([3,30,34,5,9]))
# Out:
# 6210
# 9534330

# %% [markdown]
#       - 3, 30 sort를 계속 해보다가 애먹어서 구글링해서 찾은 답..
#       머리 좋네.. 문자열이 1000자리 이하이므로 3을 곱해줘서 3, 30 sort를 전략적으로 하는 방법임.. 굿이다

# %% [markdown]
# **다른 사람 풀이**
#
# ![image.png](attachment:image.png)

# %%
import functools

def comparator(a,b):
    t1 = a+b
    t2 = b+a
    return (int(t1) > int(t2)) - (int(t1) < int(t2)) #  t1이 크다면 1  // t2가 크다면 -1  //  같으면 0

def solution(numbers):
    n = [str(x) for x in numbers]
    n = sorted(n, key=functools.cmp_to_key(comparator),reverse=True)
    answer = str(int(''.join(n)))
    return answer

# %% [markdown]
#     comparator 라는 함수를 만들어서,
#     functools.cmp_to_key 를 사용했음.. 이것도 굿이다 정말
